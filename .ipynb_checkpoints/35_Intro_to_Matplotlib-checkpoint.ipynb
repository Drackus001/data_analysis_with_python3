# %%
# Importing Libraries
import pandas as pd
import numpy as np
import datetime
from datetime import datetime

# %%
# matplotlib
import matplotlib as mpl

# matplotlib plotting functions
import matplotlib.pyplot as plt

# we want our plots inline
# %matplotlib inline

# %%
Sales1 = pd.Series([200, 500, 300, 400], index=['Microsoft', 'Facebook', 'Google', 'MyCompany'])
Sales2 = pd.Series([150, 240, 210, 490], index=['Microsoft', 'Facebook', 'Google', 'MyCompany'])
Sales3 = pd.Series([300, 400, 500, 900], index=['Microsoft', 'Facebook', 'Google', 'MyCompany'])

# %%
Dataframe1 = pd.DataFrame({2017: Sales1, 2018: Sales2, 2019: Sales3})
Dataframe1
# Out:
#            2017  2018  2019
# Microsoft   200   150   300
# Facebook    500   240   400
# Google      300   210   500
# MyCompany   400   490   900

# %%
Dataframe1.plot()

# %%
Series1 = pd.Series(np.random.randn(911), index=pd.date_range("2017-1-1", "2019-6-30"))

# %%
Series1.plot()

# %%
Series2 = Series1.cumsum()
Series2.plot()
